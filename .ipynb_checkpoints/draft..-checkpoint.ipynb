# %%
# numpy for high level mathematical functions and working with Arrays
import numpy as np
# pandas data manipulation and analysis for tablular data
import pandas as pd
#seaborn and matplotlib for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import chardet

# %%
df = pd.read_csv("USState_codes.csv", index_col = 0)
df.head()
# Out:
#            Abbreviation
# US_State
# Alabama              AL
# Alaska               AK
# Arizona              AZ
# Arkansas             AR
# California           CA

# %%
df1 = pd.read_csv('AviationData.csv', encoding='ISO-8859-1', dtype={'column_6_name': str, 'column_7_name': float, 'column_28_name': int})
# Out:
# <ipython-input-4-c129645cd5d9>:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('AviationData.csv', encoding='ISO-8859-1', dtype={'column_6_name': str, 'column_7_name': float, 'column_28_name': int})

# %%
df1 = pd.read_csv('AviationData.csv', encoding='ISO-8859-1', low_memory=False)
df1.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
df1.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Columns: 31 entries, Event.Id to Publication.Date
# dtypes: float64(5), object(26)
# memory usage: 21.0+ MB

# %%
df1.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df1.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38640
# Airport.Name              36099
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1317
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
# To sort the missing values in descendng order..
df1.isnull().sum().sort_values(ascending = False)
# Out:
# Schedule                  76307
# Air.carrier               72241
# FAR.Description           56866
# Aircraft.Category         56602
# Longitude                 54516
# Latitude                  54507
# Airport.Code              38640
# Airport.Name              36099
# Broad.phase.of.flight     27165
# Publication.Date          13771
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Fatal.Injuries      11401
# Engine.Type                7077
# Report.Status              6381
# Purpose.of.flight          6192
# Number.of.Engines          6084
# Total.Uninjured            5912
# Weather.Condition          4492
# Aircraft.damage            3194
# Registration.Number        1317
# Injury.Severity            1000
# Country                     226
# Amateur.Built               102
# Model                        92
# Make                         63
# Location                     52
# Investigation.Type            0
# Event.Date                    0
# ...

# %%
df1.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df2.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Event.Date                    0
# Location                     52
# Country                     226
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7077
# Purpose.of.flight          6192
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Report.Status              6381
# dtype: int64

# %%
# Out:
# 0        ID
# 1        CA
# 2        VA
# 3        CA
# 4        OH
#          ..
# 88884    MD
# 88885    NH
# 88886    AZ
# 88887    UT
# 88888    GA
# Name: Abbreviation, Length: 88889, dtype: object

# %%
# Out:
#          Event.Id Investigation.Type  Event.Date         Location  \
# 0  20001218X45444           Accident  1948-10-24  MOOSE CREEK, ID
# 1  20001218X45447           Accident  1962-07-19   BRIDGEPORT, CA
# 2  20061025X01555           Accident  1974-08-30    Saltville, VA
# 3  20001218X45448           Accident  1977-06-19       EUREKA, CA
# 4  20041105X01764           Accident  1979-08-02       Canton, OH
#
#          Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 0  United States        Fatal(2)       Destroyed               NaN   Stinson
# 1  United States        Fatal(4)       Destroyed               NaN     Piper
# 2  United States        Fatal(3)       Destroyed               NaN    Cessna
# 3  United States        Fatal(2)       Destroyed               NaN  Rockwell
# 4  United States        Fatal(1)       Destroyed               NaN    Cessna
#
#       Model Amateur.Built  Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
df2.isna().sum().sort_values(ascending = False)
# Out:
# Aircraft.Category         53072
# Total.Serious.Injuries    11003
# Total.Minor.Injuries      10336
# Total.Fatal.Injuries       9911
# Total.Uninjured            5285
# Number.of.Engines          2239
# Engine.Type                1294
# Injury.Severity              14
# Event.Id                      0
# Report.Status                 0
# Purpose.of.flight             0
# Amateur.Built                 0
# Investigation.Type            0
# Model                         0
# Make                          0
# Aircraft.damage               0
# Country                       0
# Location                      0
# Event.Date                    0
# Abbreviation                  0
# dtype: int64

# %%
df2.tail(4)
# Out:
#              Event.Id Investigation.Type  Event.Date        Location  \
# 88647  20221011106098           Accident  2022-10-08      Dacula, GA
# 88661  20221018106153           Accident  2022-10-13     Ardmore, OK
# 88735  20221031106231           Accident  2022-10-29     Houston, TX
# 88767  20221109106272           Accident  2022-11-09  Bridgeport, TX
#
#              Country Injury.Severity Aircraft.damage Aircraft.Category  \
# 88647  United States       Non-Fatal     Substantial          Airplane
# 88661  United States       Non-Fatal     Substantial          Airplane
# 88735  United States           Minor     Substantial          Airplane
# 88767  United States       Non-Fatal     Substantial          Airplane
#
#                     Make   Model Amateur.Built  Number.of.Engines  \
# 88647             CESSNA   177RG            No                1.0
# 88661              BEECH    B-60            No                2.0
# ...

# %%
# Out:
# Non-Fatal     61436
# Fatal(1)       5881
# Fatal(2)       3574
# Fatal          2819
# Incident       1129
#               ...
# Fatal(54)         1
# Fatal(65)         1
# Fatal(72)         1
# Fatal(160)        1
# Fatal(132)        1
# Name: Injury.Severity, Length: 78, dtype: int64

# %%
# Out:
# 61436

# %%
# Out:
# 'Non-Fatal'

# %%
# Out:
# <ipython-input-23-b94e863ed480>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Injury.Severity'].fillna('Non_fatal', inplace = True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.isna().sum().sort_values(ascending = False)
# Out:
# Aircraft.Category         53072
# Total.Serious.Injuries    11003
# Total.Minor.Injuries      10336
# Total.Fatal.Injuries       9911
# Total.Uninjured            5285
# Number.of.Engines          2239
# Engine.Type                1294
# Event.Id                      0
# Report.Status                 0
# Purpose.of.flight             0
# Amateur.Built                 0
# Investigation.Type            0
# Model                         0
# Make                          0
# Aircraft.damage               0
# Injury.Severity               0
# Country                       0
# Location                      0
# Event.Date                    0
# Abbreviation                  0
# dtype: int64

# %%
# Out:
# Airplane             21072
# Helicopter            2298
# Glider                 457
# Gyrocraft              150
# Weight-Shift           149
# Balloon                125
# Powered Parachute       84
# Ultralight              24
# Blimp                    4
# Unknown                  2
# Powered-Lift             2
# WSFT                     1
# Name: Aircraft.Category, dtype: int64

# %%
# Out:
# array([nan, 'Airplane', 'Helicopter', 'Glider', 'Balloon', 'Gyrocraft',
#        'Ultralight', 'Unknown', 'Blimp', 'Powered-Lift', 'Weight-Shift',
#        'Powered Parachute', 'WSFT'], dtype=object)

# %%
# Out:
# 0

# %%
# Out:
# Personal                   15733
# Business                     804
# Public Aircraft - Local       56
# Public Aircraft               55
# Name: Purpose.of.flight, dtype: int64

# %%
# Applying multiple aggregation function on the columns below to deal missing value in 
df2[["Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Fatal.Injuries","Total.Uninjured",
                   "Number.of.Engines"]].agg(['sum', 'max', 'median', 'mean'])
# Out:
#         Total.Serious.Injuries  Total.Minor.Injuries  Total.Fatal.Injuries  \
# sum                5595.000000           5375.000000           8097.000000
# max                  44.000000            380.000000            228.000000
# median                0.000000              0.000000              0.000000
# mean                  0.267154              0.251615              0.386344
#
#         Total.Uninjured  Number.of.Engines
# sum           35516.000       25331.000000
# max             588.000           8.000000
# median            1.000           1.000000
# mean              1.517           1.071214

# %%
df2["Total.Serious.Injuries"].fillna(0, inplace = True)
df2["Total.Minor.Injuries"].fillna(0, inplace = True)
df2["Total.Fatal.Injuries"].fillna(0, inplace = True)
df2["Total.Uninjured"].fillna(0, inplace = True)
df2["Number.of.Engines"].fillna(0, inplace = True)

# %%
df2.isna().sum()
# Out:
# Event.Id                    0
# Investigation.Type          0
# Event.Date                  0
# Location                    0
# Country                     0
# Injury.Severity             0
# Aircraft.damage             0
# Aircraft.Category           0
# Make                        0
# Model                       0
# Amateur.Built               0
# Number.of.Engines           0
# Engine.Type               701
# Purpose.of.flight           0
# Total.Fatal.Injuries        0
# Total.Serious.Injuries      0
# Total.Minor.Injuries        0
# Total.Uninjured             0
# Report.Status               0
# Abbreviation                0
# dtype: int64

# %%
df2["Engine.Type"].value_counts()
# converting the categorical type to list..
mode = df2["Engine.Type"].value_counts().index.tolist()
mode[0]
# Out:
# 'Reciprocating'

# %%
df2["Engine.Type"].fillna(mode[0], inplace = True)

# %%
# converting the categorical type to list
#df4 = df2["Engine.Type"].value_counts().tolist()
#df4[1]

# %%
#df2["Engine.Type"].mode()[0]

# %%
df2.isna().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Report.Status             0
# Abbreviation              0
# dtype: int64

# %%
df2["Country"].value_counts()
# Out:
# United States                     24051
# Mexico                               26
# Brazil                               22
# Canada                               17
# Germany                              16
#                                   ...
# Federated States Of Micronesia        1
# Gabon                                 1
# Niger                                 1
# Paraguay                              1
# Obyan                                 1
# Name: Country, Length: 77, dtype: int64

# %%
# filtering to have United States as the Country
df4 = df2[df2["Country"] == "United States"]
df4
# Out:
#              Event.Id Investigation.Type  Event.Date          Location  \
# 7      20020909X01562           Accident  1982-01-01       PULLMAN, WA
# 8      20020909X01561           Accident  1982-01-01  EAST HANOVER, NJ
# 12     20020917X02148           Accident  1982-01-02         HOMER, LA
# 13     20020917X02134           Accident  1982-01-02        HEARNE, TX
# 14     20020917X02119           Accident  1982-01-02     CHICKASHA, OK
# ...               ...                ...         ...               ...
# 88639  20221011106092           Accident  2022-10-06          Iola, TX
# 88647  20221011106098           Accident  2022-10-08        Dacula, GA
# 88661  20221018106153           Accident  2022-10-13       Ardmore, OK
# 88735  20221031106231           Accident  2022-10-29       Houston, TX
# 88767  20221109106272           Accident  2022-11-09    Bridgeport, TX
#
#              Country Injury.Severity Aircraft.damage Aircraft.Category  \
# ...

# %%
# Analysis of the Make feature..
df2["Make"].value_counts()
# Out:
# CESSNA                         3682
# Cessna                         3277
# PIPER                          2180
# Piper                          1723
# BEECH                           730
#                                ...
# AIR GULFSTREAM AIRLINES INC       1
# ENGLISH ELECTRIC LIGHTNING        1
# Robert Wood                       1
# PARADISE USA LLC                  1
# STEPHEN J HOFFMAN                 1
# Name: Make, Length: 4119, dtype: int64

# %%
df2["Make"].str.lower()
# Out:
# 7                   cessna
# 8                   cessna
# 12                bellanca
# 13                  cessna
# 14                  navion
#                ...
# 88639               cessna
# 88647               cessna
# 88661                beech
# 88735    stephen j hoffman
# 88767             luscombe
# Name: Make, Length: 24368, dtype: object

# %%
df2_make = df2["Make"].str.capitalize()
df2_make
# Out:
# 7                   Cessna
# 8                   Cessna
# 12                Bellanca
# 13                  Cessna
# 14                  Navion
#                ...
# 88639               Cessna
# 88647               Cessna
# 88661                Beech
# 88735    Stephen j hoffman
# 88767             Luscombe
# Name: Make, Length: 24368, dtype: object

# %%
df2_make.drop_duplicates(inplace = True)

# %%
df2_make.duplicated().any()
# Out:
# False

# %%
df2.head(4)
# Out:
#           Event.Id Investigation.Type  Event.Date          Location  \
# 7   20020909X01562           Accident  1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident  1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident  1982-01-02         HOMER, LA
# 13  20020917X02134           Accident  1982-01-02        HEARNE, TX
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
#
#      Model Amateur.Built  Number.of.Engines    Engine.Type Purpose.of.flight  \
# 7      140            No                1.0  Reciprocating          Personal
# 8     401B            No                2.0  Reciprocating          Business
# ...

# %%
df2.head()
# Out:
#           Event.Id Investigation.Type  Event.Date          Location  \
# 7   20020909X01562           Accident  1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident  1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident  1982-01-02         HOMER, LA
# 13  20020917X02134           Accident  1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident  1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model Amateur.Built  Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
# Checking the datatypes for each column..
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24368 entries, 7 to 88767
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                24368 non-null  object
#  1   Investigation.Type      24368 non-null  object
#  2   Event.Date              24368 non-null  object
#  3   Location                24368 non-null  object
#  4   Country                 24368 non-null  object
#  5   Injury.Severity         24368 non-null  object
#  6   Aircraft.damage         24368 non-null  object
#  7   Aircraft.Category       24368 non-null  object
#  8   Make                    24368 non-null  object
#  9   Model                   24368 non-null  object
#  10  Amateur.Built           24368 non-null  object
#  11  Number.of.Engines       24368 non-null  float64
#  12  Engine.Type             24368 non-null  object
#  13  Purpose.of.flight       24368 non-null  object
# ...

# %%
# Convert Event.Date from object to datetime
df2['Event.Date'] = pd.to_datetime(df2['Event.Date'])
df2['Event.Date']
# Out:
# 7       1982-01-01
# 8       1982-01-01
# 12      1982-01-02
# 13      1982-01-02
# 14      1982-01-02
#            ...
# 88639   2022-10-06
# 88647   2022-10-08
# 88661   2022-10-13
# 88735   2022-10-29
# 88767   2022-11-09
# Name: Event.Date, Length: 24368, dtype: datetime64[ns]

# %%
# The Event.Date has been converted to datetime64[ns] datatype..
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24368 entries, 7 to 88767
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                24368 non-null  object
#  1   Investigation.Type      24368 non-null  object
#  2   Event.Date              24368 non-null  datetime64[ns]
#  3   Location                24368 non-null  object
#  4   Country                 24368 non-null  object
#  5   Injury.Severity         24368 non-null  object
#  6   Aircraft.damage         24368 non-null  object
#  7   Aircraft.Category       24368 non-null  object
#  8   Make                    24368 non-null  object
#  9   Model                   24368 non-null  object
#  10  Amateur.Built           24368 non-null  object
#  11  Number.of.Engines       24368 non-null  float64
#  12  Engine.Type             24368 non-null  object
#  13  Purpose.of.flight       24368 non-null  object
# ...

# %%
# Extract the year
df2['Event.Year'] = df2['Event.Date'].dt.year

# %%
df2.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ... Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
df2["Make"].value_counts()
# Out:
# CESSNA                         3682
# Cessna                         3277
# PIPER                          2180
# Piper                          1723
# BEECH                           730
#                                ...
# AIR GULFSTREAM AIRLINES INC       1
# ENGLISH ELECTRIC LIGHTNING        1
# Robert Wood                       1
# PARADISE USA LLC                  1
# STEPHEN J HOFFMAN                 1
# Name: Make, Length: 4119, dtype: int64

# %%
# Filter for models made by "Cessna" and operating in "United States"
filtered_df = df2[(df2["Country"] == "United States") & (df2["Make"] == "Cessna")]

# %%
df2_filt = df2[(df2["Country"] == "United States") & (df2["Make"] == "Cessna")]
df2_filt
# Out:
#              Event.Id Investigation.Type Event.Date          Location  \
# 7      20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8      20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 13     20020917X02134           Accident 1982-01-02        HEARNE, TX
# 17     20020917X01656           Accident 1982-01-02       SKWENTA, AK
# 18     20020917X02481           Accident 1982-01-02       GALETON, PA
# ...               ...                ...        ...               ...
# 85358  20200921X15712           Accident 2020-09-17    Marksville, LA
# 85360  20200918X92359           Accident 2020-09-18     Hollywood, FL
# 85380  20200922X90108           Accident 2020-09-20   San Antonio, TX
# 85387  20200922X00441           Accident 2020-09-21     Lafayette, IN
# 85668  20201209102387           Accident 2020-12-08        Dillon, MT
#
#              Country Injury.Severity Aircraft.damage Aircraft.Category  \
# ...

# %%
# Analysis for the Investigation.Type...
df2["Investigation.Type"].value_counts()
# Out:
# Accident    24094
# Incident      274
# Name: Investigation.Type, dtype: int64

# %%
df2.groupby("Investigation.Type").sum()
# Out:
#                     Number.of.Engines  Total.Fatal.Injuries  \
# Investigation.Type
# Accident                      24969.0                8097.0
# Incident                        362.0                   0.0
#
#                     Total.Serious.Injuries  Total.Minor.Injuries  \
# Investigation.Type
# Accident                            5590.0                4956.0
# Incident                               5.0                 419.0
#
#                     Total.Uninjured  Event.Year
# Investigation.Type
# Accident                    30595.0    48377412
# Incident                     4921.0      547693

# %%
df5 = df2[df2["Investigation.Type"] == "Accident"]
df5.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ... Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
df5.isna().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Report.Status             0
# Abbreviation              0
# Event.Year                0
# dtype: int64

# %%
df2.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ... Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %% [markdown]
# ## Univariate data analysis..

# %%
# Here the data is cleaned and ready for EDA ...

# %%
# Performing a univariate analysis on the Number.of.Engines..
# Histogram for Number of Engines to check the distribution
# df2["Number.of.Engines"]

# %%
# Convert 'Number.of.Engines' from float to integer
df2['Number.of.Engines'] = df2['Number.of.Engines'].astype(int)

# %%
df2['Number.of.Engines'].value_counts()
# Out:
# 1    21205
# 2     1980
# 0     1138
# 3       22
# 4       21
# 8        2
# Name: Number.of.Engines, dtype: int64

# %%
df2['Number.of.Engines'].unique()
# Out:
# array([1, 2, 0, 4, 3, 8])

# %%
# Create a figure and ax object
fig, ax = plt.subplots(figsize=(8, 6))

# Plotting the histogram on the ax
ax.hist(df2['Number.of.Engines'], bins=range(min(df2['Number.of.Engines']), max(df2['Number.of.Engines']) + 2), edgecolor='black')

# Customizing the plot for the Histogram..
ax.set_title('Distribution of Number of Engines')
ax.set_xlabel('Number of Engines')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %%
# The histogram has one peak which means that most of the planes tend to have similar value for the Number.of.Engines..
# for the plane with one engine it has the highest peak which further means that its the most common number of engines..

#From the graph its evident that most of the Airplanes engines fall from the range 0 - 8. I have also observed that from
# the range there are no probable outliers since these engines numbers fall within the specified range ..

# From the analysis its noted that most of the Airplanes have fewer engines with exception of but few which might be having 
# significantly more number of engines..


#RECOMMENDATIONS... # for this company i would recommend that we purchase the Airplanes with few Number of Engines since 
# they have shown significant number of Airplanes considering them for both Private and Commercial enterprises

# %%
df2.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ... Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
grouped_df2 = df2.groupby('Make')['Number.of.Engines'].mean().reset_index()
grouped_df2
#grouped_df2["Make"].value_counts().head()
# Out:
#                      Make  Number.of.Engines
# 0                    1200                0.0
# 1               177MF LLC                1.0
# 2     2007 Savage Air LLC                1.0
# 3             2021FX3 LLC                1.0
# 4              781569 INC                1.0
# ...                   ...                ...
# 4114             Ziermann                1.0
# 4115                 Zlin                1.0
# 4116        Zlin Aviation                1.0
# 4117         de Havilland                1.2
# 4118              unknown                1.0
#
# [4119 rows x 2 columns]

# %%
df2.isna().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Report.Status             0
# Abbreviation              0
# Event.Year                0
# dtype: int64

# %%
df2['Make']
# Out:
# 7                   Cessna
# 8                   Cessna
# 12                Bellanca
# 13                  Cessna
# 14                  Navion
#                ...
# 88639               CESSNA
# 88647               CESSNA
# 88661                BEECH
# 88735    STEPHEN J HOFFMAN
# 88767             LUSCOMBE
# Name: Make, Length: 24368, dtype: object

# %%
# group purpose of flight and make then count the number of flights for each Make..
purpose_df3 = df3.groupby(['Purpose.of.flight', 'Make']).size().reset_index(name = 'Count_of_Flights')
purpose_df3
# Out:
#             Purpose.of.flight                           Make  Count_of_Flights
# 0                    Business                 AERO COMMANDER                 2
# 1                    Business                 AERO VODOCHODY                 1
# 2                    Business                   AEROSPATIALE                 2
# 3                    Business         AEROSTAR INTERNATIONAL                 1
# 4                    Business                    AIR TRACTOR                 1
# ...                       ...                            ...               ...
# 3692  Public Aircraft - Local              MD HELICOPTER INC                 2
# 3693  Public Aircraft - Local   Mcdonnell Douglas Helicopter                 1
# 3694  Public Aircraft - Local  Mcdonnell Douglas Helicopters                 1
# 3695  Public Aircraft - Local                          PIPER                 2
# 3696  Public Aircraft - Local                       Robinson                 2
#
# [3697 rows x 3 columns]

# %%
# Creating a barplot visualizaing Number of flights for each make and purpose of flight..
purpose_df3 = df3.groupby(['Purpose.of.flight', 'Make']).size().reset_index(name = 'Count_of_Flights')
purpose_df3

plt.figure(figsize = (10, 6))
sns.barplot (x = 'Make', y = 'Count_of_Flights', hue = 'Purpose.of.flight', data = purpose_df3.tail(5))
plt.title('Count of Flights by Purpose of flight and Make')
plt.xlabel('Aircraft Make')
plt.ylabel('Number of Flights')
plt.xticks(rotation = 45)
plt.show()

# %%
df2.isna().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Report.Status             0
# Abbreviation              0
# Event.Year                0
# Safety_Score              0
# dtype: int64

# %%
agg_stats = df2[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']].agg(['mean', pd.Series.mode])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\apply.py in agg_list_like(self)
#     424         try:
# --> 425             concatenated = concat(results, keys=keys, axis=1, sort=False)
#     426         except TypeError as err:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#
# ...

# %%
df2.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ... Number.of.Engines    Engine.Type Purpose.of.flight  \
# ...

# %%
df = df.reset_index()
df
# Out:
#     level_0  index        US_State Abbreviation
# 0         0      0         Alabama           AL
# 1         1      1          Alaska           AK
# 2         2      2         Arizona           AZ
# 3         3      3        Arkansas           AR
# 4         4      4      California           CA
# ..      ...    ...             ...          ...
# 57       57     57  Virgin Islands           VI
# 58       58     58   Washington_DC           DC
# 59       59     59  Gulf of mexico           GM
# 60       60     60  Atlantic ocean           AO
# 61       61     61   Pacific ocean           PO
#
# [62 rows x 4 columns]

# %%
# assigning safety weightage
Fatal = 6
Serious = 3
Minor = 1

# calculating safety score..
df2['Safety_Score'] =   (df2['Total.Fatal.Injuries'] * Fatal
                                  + df2['Total.Serious.Injuries'] * Serious
                                  + df2['Total.Minor.Injuries'] * Minor)
df2.head()
# Out:
#           Event.Id Investigation.Type Event.Date          Location  \
# 7   20020909X01562           Accident 1982-01-01       PULLMAN, WA
# 8   20020909X01561           Accident 1982-01-01  EAST HANOVER, NJ
# 12  20020917X02148           Accident 1982-01-02         HOMER, LA
# 13  20020917X02134           Accident 1982-01-02        HEARNE, TX
# 14  20020917X02119           Accident 1982-01-02     CHICKASHA, OK
#
#           Country Injury.Severity Aircraft.damage Aircraft.Category      Make  \
# 7   United States       Non-Fatal     Substantial          Airplane    Cessna
# 8   United States       Non-Fatal     Substantial          Airplane    Cessna
# 12  United States       Non-Fatal       Destroyed          Airplane  Bellanca
# 13  United States        Fatal(1)       Destroyed          Airplane    Cessna
# 14  United States        Fatal(1)       Destroyed          Airplane    Navion
#
#      Model  ...    Engine.Type  Purpose.of.flight Total.Fatal.Injuries  \
# ...

# %%
df1_2 = df2.merge(df, on = "Abbreviation") # extract Abbreviation from the df dataset..
df1_2.head()
# Out:
#          Event.Id Investigation.Type Event.Date      Location        Country  \
# 0  20020909X01562           Accident 1982-01-01   PULLMAN, WA  United States
# 1  20020917X02574           Accident 1982-01-08   PULLMAN, WA  United States
# 2  20020917X02575           Accident 1982-01-13   SPOKANE, WA  United States
# 3  20020917X02576           Accident 1982-01-15   SPOKANE, WA  United States
# 4  20020917X02624           Accident 1982-01-18  ORCHARDS, WA  United States
#
#   Injury.Severity Aircraft.damage Aircraft.Category    Make      Model  ...  \
# 0       Non-Fatal     Substantial          Airplane  Cessna        140  ...
# 1       Non-Fatal     Substantial          Airplane  Cessna     TU206G  ...
# 2       Non-Fatal     Substantial          Airplane   Piper  PA-31-350  ...
# 3       Non-Fatal     Substantial          Airplane  Cessna        140  ...
# 4       Non-Fatal       Destroyed          Airplane   Beech        C23  ...
#
# ...

# %%
df1_2.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Event.Date', 'Location', 'Country',
#        'Injury.Severity', 'Aircraft.damage', 'Aircraft.Category', 'Make',
#        'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type',
#        'Purpose.of.flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Report.Status',
#        'Abbreviation', 'Event.Year', 'Safety_Score', 'level_0', 'index',
#        'US_State'],
#       dtype='object')

# %%
cleaned_df = df
cleaned_df.to_csv('cleaned_data.csv', index = False)

# %%
purpose_df2 = df2.groupby(['Purpose.of.flight', 'Make']).size().reset_index(name = 'Count_of_Flights')
purpose_df2.value_counts().sort_values(ascending = False)
# Out:
# Purpose.of.flight   Make                   Count_of_Flights
# ASHO                MX AIRCRAFT LLC        1                   1
# Aerial Application  ROBINSON HELICOPTER    10                  1
#                     AERO COMMANDER         13                  1
#                     AEROSPATIALE           2                   1
#                     AG-CAT CORPORATION     1                   1
#                                                               ..
# Unknown             Waco                   1                   1
#                     Weatherly              3                   1
#                     Williams Helicopter    1                   1
#                     Ted Smith              1                   1
#                     Zhuhai Helicopter Co.  1                   1
# Length: 5239, dtype: int64

# %%
df5 = df4.groupby(["Make", "Model"])["Injury.Severity"].value_counts().sort_values(ascending=False)
